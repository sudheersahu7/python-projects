# %%
pip install boto3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    --- ------------------------------------ 1.3/14.6 MB 8.3 MB/s eta 0:00:02
#    ------- -------------------------------- 2.9/14.6 MB 7.9 MB/s eta 0:00:02
#    -------------- ------------------------- 5.2/14.6 MB 8.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.0/14.6 MB 7.8 MB/s eta 0:00:02
#    ------------------ --------------------- 6.8/14.6 MB 7.3 MB/s eta 0:00:02
#    -------------------- ------------------- 7.6/14.6 MB 6.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 8.4/14.6 MB 6.1 MB/s eta 0:00:02
#    ------------------------- -------------- 9.2/14.6 MB 5.7 MB/s eta 0:00:01
#    -------------------------- ------------- 9.7/14.6 MB 5.4 MB/s eta 0:00:01
#    --------------------------- ------------ 10.2/14.6 MB 5.1 MB/s eta 0:00:01
# ...

# %%
import boto3
import csv
from botocore.exceptions import ClientError
#config

bucketname = constemsai002
inpcsv = "input.csv"
outcsv = "output.csv"
s3 = boto3.client("s3")
results = []
with open(inpcsv, mode = 'r') file:
    reader = csv.DictReader(file)
    for row in reader:
        filename = ["image_name"]
        try:
            s3.head_object(Bucket=bucketname, Key=filename)
        except ClientError as e:
            if e responses
