# %%
age = 20

# %%
age = int(input("enter your age:"))
if age >= 18:
   print ("you can watch")
else:
    print ("you are underage you dont watch ")
# Out:
# enter your age: 24
# you can watch

# %%
marks = int(input("enter your marks :"))
if marks >= 90:
    print("you are A grade")
elif marks >= 60:
    print("you are B grade")
else:
    print("you are C grade")
# Out:
# enter your marks : 82
# you are B grade

# %%
print("Welcome to my calculater")
print(""" 1. Addition 
          2. substraction
          3. multiplication
          4. divition""")
choise = int(input("choose to perform task"))
if choise == 1:
   num1 = int(input("write you addition number here:"))
   num2 = int(input("enter second adition numbere here:"))
   print(num1 + num2)
elif choise == 2:
     num1 = int(input("write you substraction number here:"))
     num2 = int(input("enter second numbere here:"))
     print(num1 - num2)
elif choise == 3:
   num1 = int(input("write you number here:"))
   num2 = int(input("enter second numbere here:"))
   print(num1 * num2)
elif choise == 4:
   num1 = int(input("write you number here:"))
   num2 = int(input("enter second numbere here:"))
   print(num1 / num2)
# Out:
# Welcome to my calculater
#  1. Addition
#           2. substraction
#           3. multiplication
#           4. divition
# choose to perform task 2
# write you substraction number here: 4
# enter second numbere here: 2
# 2

# %%
while True:
    print("Welcome to my calculater")
    print(""" 1. Addition 
              2. substraction
              3. multiplication
              4. divition
              5. exit """)
    choise = int(input("choose to perform task"))
    if choise == 1:
       num1 = int(input("write you addition number here:"))
       num2 = int(input("enter second adition numbere here:"))
       print("this is my final answer:", num1 + num2)
    elif choise == 2:
       num1 = int(input("write you substraction number here:"))
       num2 = int(input("enter second numbere here:"))
       print("this is my final answer:", num1 - num2)
    elif choise == 3:
       num1 = int(input("write you number here:"))
       num2 = int(input("enter second numbere here:"))
       print("this is my final answer:", num1 * num2)
    elif choise == 4:
       num1 = int(input("write you number here:"))
       num2 = int(input("enter second numbere here:"))
       print("this is my final answer:", num1 / num2)
    elif choise == 5:
       print("program exit")
       break
# Out:
# Welcome to my calculater
#  1. Addition
#               2. substraction
#               3. multiplication
#               4. divition
#               5. exit
# choose to perform task 5
# program exit
