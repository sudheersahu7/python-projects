# %%
#"""this is for function in python we are using and and how to create and use function we practice here"""

# %%
#def is use for function in python and we give name of function 
def my_function ():
    x = 7.58
    print (x)
(my_function())
#print() = waiter shows the dish to you 👀

#return = waiter gives the dish back to the kitchen to use in another recipe 🍲
# Out:
# 7.58

# %%
    def my_collage_result():
        results = {
            "1": "not declared",
            "2": "not declared",
            "3": "6.27",
            "4": "6.50",
            "5": "7.21",
            "6": "7.38",
            "7": "7.58",
            "8": "upcoming result"
        }
        while True:
            name = input("Enter q to stop: ")
            if name == "q":
                break
            sem = input("enter your semester to know result 1-8:")
            if sem in results:
               print ("semester" , sem, "Result:", results[sem])
            else:
               print("Invalid semester")
    my_collage_result()
# Out:
# Enter q to stop:  1
# enter your semester to know result 1-8: 1
# semester 1 Result: not declared
# Enter q to stop:  .
# enter your semester to know result 1-8: 8
# semester 8 Result: upcoming result
# Enter q to stop:  4
# enter your semester to know result 1-8: 9
# Invalid semester
# Enter q to stop:  4
# enter your semester to know result 1-8: 7
# semester 7 Result: 7.58
# Enter q to stop:  q
